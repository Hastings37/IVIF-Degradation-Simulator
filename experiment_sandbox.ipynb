# %%
import torch

# %%
print(torch.__version__)
# Out:
# 1.8.0+cu111

# %%
import cv2 
ir=cv2.imread('Images/Infrared/00001D.png')
print(type(ir))
# Out:
# <class 'numpy.ndarray'>

# %%
ir.shape
# Out:
# (480, 640, 3)

# %%
ir[:,:,0]==ir[:,:,1]
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
from PIL import Image 
ir_pil=Image.open('Images/Infrared/00001D.png')
print(type(ir_pil))
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
import numpy as np 
ir_pil_numpy=np.array(ir_pil)
print(ir_pil_numpy.shape )
# Out:
# (480, 640)

# %%
img = cv2.imread('Images/Infrared/00001D.png', cv2.IMREAD_GRAYSCALE)
img.shape
# Out:
# (480, 640)

# %%
vis=cv2.imread('Images/Visible/00001D.png', cv2.IMREAD_COLOR)
print(vis.shape)
# Out:
# (480, 640, 3)

# %%
print(vis[0,0,0].dtype)
# Out:
# uint8

# %%
ir.shape
# Out:
# (480, 640, 3)

# %%
cv2.imwrite('ir_gray.png', ir[:,:,0])
# Out:
# True

# %%
ir_cv2_gray=cv2.imread('ir_gray.png', cv2.IMREAD_GRAYSCALE)
print(ir_cv2_gray.shape)
# Out:
# (480, 640)

# %%
ir=cv2.imread('Images/Infrared/00001D.png',cv2.IMREAD_GRAYSCALE)
cv2.imwrite('ir_gray_2.png', ir)
# .astype 将其转换为 uint8 类型
# Out:
# True

# %%
img.shape
# Out:
# (480, 640)

# %%
# img=np.concatenate((img,img,img),axis=2)
# from Visible.vis_rain import alpha_rain
# alpha_rain(img)
img = img[..., None]  # H×W → H×W×1
img = np.concatenate([img, img, img], axis=2)  # H×W×3
# img[...,None]  这样的通道的扩展的操作；
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 img=np.concatenate((img,img,img),axis=2)
#       2 from Visible.vis_rain import alpha_rain
#       3 alpha_rain(img)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# AxisError: axis 2 is out of bounds for array of dimension 2
